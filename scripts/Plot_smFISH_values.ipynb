# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
# specify the datasets for your plot
df = pd.read_csv('/Users/laurabreimann/Desktop/Inga/database/total_database.csv')

# %%
df.head()
# Out:
#    count                      id shRNA       area  smFISH_per_area
# 0     89    ActB_Puro_Map2_scr15  ctrl  1592.9277         0.055872
# 1     47    ActB_Puro_Map2_scr14  ctrl   827.0924         0.056826
# 2     87    ActB_Puro_Map2_scr16  ctrl  1352.9030         0.064306
# 3     82    ActB_Puro_Map2_scr17  ctrl  1420.6168         0.057721
# 4     15  ActB_Puro_Map2_scr19_1  ctrl   458.5004         0.032715

# %%
sns.reset_defaults()

# Create figure instance
fig, ax = plt.subplots(figsize=(4.5, 5))


#removing top and right borders
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)


# Add boxplot
sns.boxplot(x=df['shRNA'],y=df['smFISH_per_area'],
hue=df['shRNA'], palette=["m", "g"])


sns.stripplot(x=df['shRNA'],y=df['smFISH_per_area'], hue=df['shRNA'], dodge=True)

plt.ylabel('actin-ß-Puro-PLA per area', fontsize=15) 
plt.title('translation events in neurites')
#plt.ylim(0.8, 1)
#plt.xlim(-0.1,1.7)
plt.xticks(fontsize=10)
 

#  Show and save the figure
plt.tight_layout()
plt.savefig('smFISH_per_area.png', dpi=300)
plt.show()

# %%
Sample1 = df.loc[df['shRNA'] == 'ctrl']
Sample2 = df.loc[df['shRNA'] == 'shLarp']

# %%
t, p = stats.ttest_ind(Sample1['smFISH_per_area'],Sample2['smFISH_per_area'], equal_var = True)
print("t-statistic of "  + str(np.unique(Sample1['smFISH_per_area'])) + " vs "+ str(np.unique(Sample2['smFISH_per_area']))+ "= " + str(t))
print("p-value of "  + str(np.unique(Sample1['smFISH_per_area'])) + " vs "+ str(np.unique(Sample2['smFISH_per_area']))+ " = " + str(p))
# Out:
# t-statistic of [0.00885028 0.02003837 0.0206752  0.02197311 0.03271535 0.03379023
#  0.0371687  0.04122549 0.04211891 0.04263837 0.04300705 0.04356939
#  0.04501181 0.04810071 0.05377108 0.05405593 0.05587196 0.05682557
#  0.05772141 0.05953617 0.06047999 0.06117686 0.06360571 0.06430616
#  0.06701193 0.08430454 0.1071392  0.11241819 0.11462231 0.11871494
#  0.12279968 0.12458148 0.15138009 0.15282633 0.16697648 0.18115335
#  0.18421562 0.21189932 0.21987968 0.22280623 0.25306381 0.26098497] vs [0.01284031 0.01423165 0.01756553 0.01912072 0.02008443 0.02043811
#  0.02082237 0.0212104  0.02329196 0.02349969 0.02369508 0.02459543
#  0.02562617 0.026691   0.02729419 0.02756442 0.02935044 0.02982737
#  0.03011521 0.03071331 0.03130097 0.03201405 0.03394636 0.0340551
#  0.03491222 0.03551947 0.03731567 0.03884232 0.03914702 0.03977038
#  0.0406297  0.04294444 0.04419949 0.04583222 0.04719172 0.05177936
#  0.05370859 0.07847742]= 5.365588642855943
# p-value of [0.00885028 0.02003837 0.0206752  0.02197311 0.03271535 0.03379023
#  0.0371687  0.04122549 0.04211891 0.04263837 0.04300705 0.04356939
#  0.04501181 0.04810071 0.05377108 0.05405593 0.05587196 0.05682557
#  0.05772141 0.05953617 0.06047999 0.06117686 0.06360571 0.06430616
#  0.06701193 0.08430454 0.1071392  0.11241819 0.11462231 0.11871494
#  0.12279968 0.12458148 0.15138009 0.15282633 0.16697648 0.18115335
#  0.18421562 0.21189932 0.21987968 0.22280623 0.25306381 0.26098497] vs [0.01284031 0.01423165 0.01756553 0.01912072 0.02008443 0.02043811
#  0.02082237 0.0212104  0.02329196 0.02349969 0.02369508 0.02459543
#  0.02562617 0.026691   0.02729419 0.02756442 0.02935044 0.02982737
#  0.03011521 0.03071331 0.03130097 0.03201405 0.03394636 0.0340551
#  0.03491222 0.03551947 0.03731567 0.03884232 0.03914702 0.03977038
#  0.0406297  0.04294444 0.04419949 0.04583222 0.04719172 0.05177936
#  0.05370859 0.07847742] = 8.027131584122448e-07
